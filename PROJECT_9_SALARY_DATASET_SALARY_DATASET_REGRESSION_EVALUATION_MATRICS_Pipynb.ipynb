# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/sample_data/Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.size
# Out:
# 60

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().any(axis=1) # axis 1 reprents rows in pandas, axis 0 reprensts columns
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.figure(dpi=120)
#plt.legend(['Salary'])
plt.xlabel(['YearsExperience'])
plt.ylabel(['Salary'])
plt.title('years of exeperience and salary')
plt.scatter(df['YearsExperience'],df['Salary'])
plt.show()
 # YE POSITIVE CORELATION DATA HAI KYUKI ISKA GRAPH NEECHE SE UPAR JA RHA......AGR UPR SE NEEVHE JAATA TO NEGATIVE CORELATION JA RHA..

# %%
X =df.iloc[:,:-1].values
Y=df.iloc[:,-1].values

# %%
print(X)
#print(Y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(Y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 76056.87765504,  63155.62593389,  63155.62593389,  36360.71851304,
#        127661.88453965, 125677.07658255, 118730.2487327 ,  82011.30152634,
#         53231.58614839])

# %%
y_test
# Out:
# array([ 83088.,  56957.,  55794.,  46205., 121872., 122391., 112635.,
#         81363.,  60150.])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_pred,y_test)
# Out:
# 5908.175659173816

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 40968991.53075547

# %%
from sklearn.metrics import mean_squared_error

# Calculate MSE
mse = mean_squared_error(y_pred, y_test)

# Calculate RMSE manually if needed
rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Squared Error (MSE): 40968991.53075547
# Root Mean Squared Error (RMSE): 6400.70242479335

# %%
from sklearn.metrics import mean_squared_log_error
mean_squared_log_error(y_pred,y_test)
# Out:
# 0.012431115471372683

# %%
reg.score(x_test,y_test) # is TRAH SE ACCURACY NIKALTE HAI TEST KA...
# Out:
# 0.9490241214820339

# %%
  reg.score(x_train,y_train) # IS TRAH SE ACCURACY TRAIN KI NIKALTE HAI...
# Out:
# 0.9556826361607201

# %% [markdown]
# # ***ROOT MEAN SQUARED ERROR AATI HAI REGRESSION PROBLEMS MAI...***
